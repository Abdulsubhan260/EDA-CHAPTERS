# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
print(sns.get_dataset_names())
tips=sns.load_dataset("tips")
tips.head()
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ## subset for relative columns:

# %%
df=tips[['total_bill','tip','sex','smoker','day','time','size']]
df.head(15)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_')
#we use this if our data in file have empty spaces it add underscroll between them
print(df.columns.tolist())
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %% [markdown]
# ##   Average tips based on number of customers:
# in this we finding average tips given by customers on basis of number of customers on single tabel.after analyzing the data set we find out tips varies on number of customers on a table.
#
#
#
# on average the tabel of 1 people gives 1.43$ tip.
#
#
#
# the tabel of two person gives 2.58$ tip.
#
#
#
# the tabel of 4 people gives 4$ tip and so on.

# %%
tips = sns.load_dataset("tips")


group_tips = tips.groupby("size")["tip"].mean().reset_index()

print(group_tips)
# Out:
#    size       tip
# 0     1  1.437500
# 1     2  2.582308
# 2     3  3.393158
# 3     4  4.135405
# 4     5  4.028000
# 5     6  5.225000

# %% [markdown]
# ## Average Number Of Visits On Each day:
# after analyzing data set avergae number of visitors in the resturant are:
#
#
#
#
# On average, each day in the dataset has 61 visits.
#
# Saturday (87) and Sunday (76) are busier than the average.
#
# Friday (19) is less busy.

# %%
day_counts = df['day'].value_counts()
print("Day-wise counts:")
print(day_counts)

average_days = day_counts.mean()
print(f" {average_days}")
# Out:
# Day-wise counts:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64
#  61.0

# %% [markdown]
# ## Importing Files Again for diffrent functions:

# %%
df=pd.read_csv("tips1.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1=pd.read_csv("tips2.csv")
df1.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 117       29.03  5.92    Male     No   Sat  Dinner     3
# 118       27.18  2.00  Female    Yes   Sat  Dinner     2
# 119       22.67  2.00    Male    Yes   Sat  Dinner     2
# 120       17.82  1.75    Male     No   Sat  Dinner     2
# 121       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  122.000000  122.000000  122.000000
# mean    19.656885    3.053607    2.475410
# std      8.098879    1.249521    0.805078
# min      3.070000    1.000000    1.000000
# 25%     14.415000    2.015000    2.000000
# 50%     18.140000    3.000000    2.000000
# 75%     23.882500    3.747500    3.000000
# max     48.270000    7.580000    4.000000

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  122.000000  122.000000  122.000000
# mean    19.915000    2.942951    2.663934
# std      9.671372    1.509058    1.072655
# min      7.250000    1.000000    1.000000
# 25%     13.000000    2.000000    2.000000
# 50%     16.700000    2.500000    2.000000
# 75%     24.542500    3.500000    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df1.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %% [markdown]
# ## Appending Files:
#
# Appending means adding more rows (new data) to our existing dataset (DataFrame).
#
# It does not replace data, it just extends it.
#
# Appending in my dataset means adding new  rows (tips) to the existing file so that you have one combined dataset for analysis.
#
# Appending use only for adding the rows.

# %%
df = pd.read_csv("tips1.csv")
df1 = pd.read_csv("tips2.csv")


append = pd.concat([df, df1], ignore_index=True)

print(append.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
append.shape
# Out:
# (244, 7)

# %% [markdown]
# ##concatination:
#
#
# Concatenation in Pandas means joining two or more datasets together.
#
# By default it stacks them row-wise (one below another like appending).
#
# But it can also work column-wise (side by side) if needed.

# %%
df=pd.read_csv("tips1.csv")
df1=pd.read_csv("tips2.csv")
concat=pd.concat([df,df1])
concat.head(15)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2

# %% [markdown]
# ## Merging:
#
# Merging means joining two datasets (tables) together using a common column (like an ID).
#
#
#  Its like matching rows from both tables where the key values are the same.
#
#
#  This helps bring related information into one table.

# %%
df=pd.read_csv("tips1.csv")
df1=pd.read_csv("tips2.csv")
merge=pd.merge(df,df1,left_index=True,right_index=True)
merge.head(20)
# Out:
#     total_bill_x  tip_x   sex_x smoker_x day_x  time_x  size_x  total_bill_y  \
# 0          16.99   1.01  Female       No   Sun  Dinner       2         14.26
# 1          10.34   1.66    Male       No   Sun  Dinner       3         15.95
# 2          21.01   3.50    Male       No   Sun  Dinner       3         12.48
# 3          23.68   3.31    Male       No   Sun  Dinner       2         29.80
# 4          24.59   3.61  Female       No   Sun  Dinner       4          8.52
# 5          25.29   4.71    Male       No   Sun  Dinner       4         14.52
# 6           8.77   2.00    Male       No   Sun  Dinner       2         11.38
# 7          26.88   3.12    Male       No   Sun  Dinner       4         22.82
# 8          15.04   1.96    Male       No   Sun  Dinner       2         19.08
# 9          14.78   3.23    Male       No   Sun  Dinner       2         20.27
# 10         10.27   1.71    Male       No   Sun  Dinner       2         11.17
# ...

# %% [markdown]
# ## Sorting data:
#
# Sorting means arranging data in a particular order so it becomes organized and easy to understand.
#
# It can be ascending order (smallest to largest A to Z) or descending order (largest to smallest Z to A).
#
# Sorting organizes information to make it easier to read, compare, and analyze.
#
#
# in my data set i sort tatal bills in ascending order (low to high).
# and also in descending order(higher to lower)

# %%
df2=pd.read_csv("Tips_1.csv")

df2.sort_values(by='total_bill', ascending=True)
# Out:
#      total_bill    tip     sex smoker   day    time  size  discount
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1      15.0
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2      15.0
# 111        7.25   1.00  Female     No   Sat  Dinner     1       NaN
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2       NaN
# 149        7.51   2.00    Male     No  Thur   Lunch     2      10.0
# ..          ...    ...     ...    ...   ...     ...   ...       ...
# 59        48.27   6.73    Male     No   Sat  Dinner     4      15.0
# 212       48.33   9.00    Male     No   Sat  Dinner     4       5.0
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3       5.0
# 30          NaN   1.45    Male     No   Sat  Dinner     2      15.0
# 31          NaN   2.50    Male     No   Sat  Dinner     4       NaN
#
# [249 rows x 8 columns]

# %%
df2.sort_values(by='total_bill', ascending=False)
# Out:
#      total_bill    tip     sex smoker  day    time  size  discount
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3       5.0
# 212       48.33   9.00    Male     No  Sat  Dinner     4       5.0
# 59        48.27   6.73    Male     No  Sat  Dinner     4      15.0
# 156       48.17   5.00    Male     No  Sun  Dinner     6      10.0
# 182       45.35   3.50    Male    Yes  Sun  Dinner     3       NaN
# ..          ...    ...     ...    ...  ...     ...   ...       ...
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2       NaN
# 92         5.75   1.00  Female    Yes  Fri  Dinner     2      15.0
# 67         3.07   1.00  Female    Yes  Sat  Dinner     1      15.0
# 30          NaN   1.45    Male     No  Sat  Dinner     2      15.0
# 31          NaN   2.50    Male     No  Sat  Dinner     4       NaN
#
# [249 rows x 8 columns]

# %% [markdown]
# ## Categorising Data:
#
# Categorizing data means grouping data into different categories or classes based on some criteria. It helps organize information so it is easier to analyze or compare.
#
#
# in my data set i categorise 0-2 = small tip.
#
# 2-5= medium tip
#
# and
#
#
# 5-10=large tip
#
#
# after running this code it cateogorise tips into small ,medium and large category so its easy to understand which customer give tip in which category.

# %%
df2['tip_category'] = pd.cut(df2['tip'], bins=[0,2,5,10], labels=['Small','Medium','Large'])
df2[["tip",'tip_category']].head()
# Out:
#     tip tip_category
# 0  1.01        Small
# 1  1.66        Small
# 2  3.50       Medium
# 3  3.31       Medium
# 4  3.61       Medium

# %% [markdown]
# ## Removing Duplicate Rows:
# in this code first i findout which rows are duplicated in my data set .it gives true if the row is duplicated and false if it not and then i remove duplicated rows by using drop method.

# %%
df2=pd.read_csv("Tips_1.csv")
df2.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 244     True
# 245     True
# 246     True
# 247     True
# 248     True
# Length: 249, dtype: bool

# %%
df2.drop_duplicates(inplace=True)
df2.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %% [markdown]
# ## Deleting or Droping Rows:
#
# Dropping rows and columns means removing unwanted data from our dataset.
#
# Dropping rows means deletes specific rows, usually based on index or condition.
#
# in this code i delted/removed all rows which have empty/NaN values.

# %%
df2=pd.read_csv("Tips_1.csv")
df2.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  discount
# 0       16.99  1.01  Female    Yes  Sun  Dinner     2      15.0
# 1       10.34  1.66    Male    Yes  Sun  Dinner     3      15.0
# 2       21.01  3.50    Male     No  Sun  Dinner     3       5.0
# 3       23.68  3.31    Male    NaN  Sun  Dinner     2       NaN
# 4       24.59  3.61  Female     No  Sun  Dinner     4      10.0
# 5       25.29   NaN    Male     No  Sun  Dinner     4      10.0
# 6        8.77   NaN    Male     No  Sun  Dinner     2      15.0
# 7       26.88   NaN    Male     No  Sun  Dinner     4       NaN
# 8       15.04  1.96    Male     No  Sun  Dinner     2       NaN
# 9       14.78  3.23    Male     No  Sun  Dinner     2      10.0

# %% [markdown]
# ## Deleting a specific row at any specific index:
# in this code i deleted any specific row on any specific index like in below code i delted row at second index.

# %%
df2=pd.read_csv("Tips_1.csv")
df2=df2.drop(index=2)
df2.head(10)
# df2.index
# Out:
#     total_bill   tip     sex smoker  day    time  size  discount
# 0        16.99  1.01  Female    Yes  Sun  Dinner     2      15.0
# 1        10.34  1.66    Male    Yes  Sun  Dinner     3      15.0
# 3        23.68  3.31    Male    NaN  Sun  Dinner     2       NaN
# 4        24.59  3.61  Female     No  Sun  Dinner     4      10.0
# 5        25.29   NaN    Male     No  Sun  Dinner     4      10.0
# 6         8.77   NaN    Male     No  Sun  Dinner     2      15.0
# 7        26.88   NaN    Male     No  Sun  Dinner     4       NaN
# 8        15.04  1.96    Male     No  Sun  Dinner     2       NaN
# 9        14.78  3.23    Male     No  Sun  Dinner     2      10.0
# 10       10.27  1.71     NaN     No  Sun  Dinner     2       5.0

# %% [markdown]
# ## Deleting a single column:
# in this code i deleted the discount column because it have too many NaN/empty values.

# %%
df2.drop('discount', axis=1)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female    Yes  Sun  Dinner     2
# 1         10.34  1.66    Male    Yes  Sun  Dinner     3
# 3         23.68  3.31    Male    NaN  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29   NaN    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 244       16.99  1.01  Female    Yes  Sun  Dinner     2
# 245       10.34  1.66    Male    Yes  Sun  Dinner     3
# 246       21.01  3.50    Male     No  Sun  Dinner     3
# 247       23.68  3.31    Male    NaN  Sun  Dinner     2
# 248       24.59  3.61  Female     No  Sun  Dinner     4
#
# [248 rows x 7 columns]

# %% [markdown]
# ##  Changing Data Format:
#
# In Changing data Frame we are converting the float into integer and we fill the missing values with fillna(0) and change its dtype into integer with astype(int)
#
# the below code fill NAN in the Booking Value column with 0(Zero).

# %%
df2['discount']=df2['discount'].fillna(0)
df2.head(10)
# Out:
#     total_bill   tip     sex smoker  day    time  size  discount
# 0        16.99  1.01  Female    Yes  Sun  Dinner     2      15.0
# 1        10.34  1.66    Male    Yes  Sun  Dinner     3      15.0
# 3        23.68  3.31    Male    NaN  Sun  Dinner     2       0.0
# 4        24.59  3.61  Female     No  Sun  Dinner     4      10.0
# 5        25.29   NaN    Male     No  Sun  Dinner     4      10.0
# 6         8.77   NaN    Male     No  Sun  Dinner     2      15.0
# 7        26.88   NaN    Male     No  Sun  Dinner     4       0.0
# 8        15.04  1.96    Male     No  Sun  Dinner     2       0.0
# 9        14.78  3.23    Male     No  Sun  Dinner     2      10.0
# 10       10.27  1.71     NaN     No  Sun  Dinner     2       5.0

# %% [markdown]
# in this code i change discount column from float to int.

# %%
df2['discount_changed'] = df2['discount'].astype(int)

df2[['discount','discount_changed']].head()
# Out:
#    discount  discount_changed
# 0      15.0                15
# 1      15.0                15
# 3       0.0                 0
# 4      10.0                10
# 5      10.0                10

# %%
df2[['discount','discount_changed']].dtypes
# Out:
# discount            float64
# discount_changed      int64
# dtype: object

# %% [markdown]
# ## Replacing Data:
# Replacing data means changing specific values in our dataset with new ones usually to fix errors or standardize information.
#
# in this code i changed customer size into small and big size.

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  discount  tip_changed  \
# 0       16.99  1.01  Female    Yes  Sun  Dinner     2      15.0         1.01
# 1       10.34  1.66    Male    Yes  Sun  Dinner     3      15.0         1.66
# 3       23.68  3.31    Male    NaN  Sun  Dinner     2       0.0         3.31
# 4       24.59  3.61  Female     No  Sun  Dinner     4      10.0         3.61
# 5       25.29   NaN    Male     No  Sun  Dinner     4      10.0          NaN
#
#    discount_changed
# 0                15
# 1                15
# 3                 0
# 4                10
# 5                10

# %% [markdown]
# ## replacing values in size with big size and small size:

# %%
df2['replaced_size']=df2['size'].replace({2:'small size',3:'big size',4:'big size'})
df2[['size','replaced_size']].head()
# Out:
#    size replaced_size
# 0     2    small size
# 1     3      big size
# 3     2    small size
# 4     4      big size
# 5     4      big size

# %% [markdown]
# ## dealing missing values:
#
# first i find which column has how many misiing values and then i remove the rows which have empty/NaN values

# %%
df2=pd.read_csv("Tips_1.csv")
df2.isnull().sum()
# Out:
# total_bill     2
# tip            3
# sex            3
# smoker         2
# day            3
# time           0
# size           0
# discount      89
# dtype: int64

# %%
df2.shape
# Out:
# (249, 8)

# %%
df2_withoutna = df2.dropna(how = 'any')
df2_withoutna.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  discount
# 0       16.99  1.01  Female    Yes  Sun  Dinner     2      15.0
# 1       10.34  1.66    Male    Yes  Sun  Dinner     3      15.0
# 2       21.01  3.50    Male     No  Sun  Dinner     3       5.0
# 4       24.59  3.61  Female     No  Sun  Dinner     4      10.0
# 9       14.78  3.23    Male     No  Sun  Dinner     2      10.0

# %%
df2_withoutna.shape
# Out:
# (152, 8)
